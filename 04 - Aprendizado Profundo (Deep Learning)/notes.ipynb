# %% [markdown]
# # Deep Learning
#
# Este notebook faz parte do meu processo de aprendizagem durante a disciplina de "Aprendizado Profundo (Deep Learning)", ministrada pela Profa. Dra. Mariana Antonia Aguiar Furucho. O objetivo é documentar o meu entendimento teórico e as práticas orientadas pela professora.
#
# ---

# %% [markdown]
# ## Do Machine Learning ao Deep Learning: a arquitetura Multi-Layer Perceptron (MLP)
#
# Modelos de deep learning:
# - deep feedforward networks (redes neurais profundas de alimentação direta)
# - feedforward neural networks (redes neurais de alimentação direta)
# - Multilayer Perceptron (MLPs, perceptrons multicamadas)
